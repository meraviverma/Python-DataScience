# %%
import numpy as np

# %%
import pandas as pd
pd.DataFrame({'A':[1,2,3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
a=1

# %%
a
# Out:
# 1

# %%
s=pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.add
# Out:
# <bound method DataFrame.add of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2013-01-02 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.sort_index(axis=1, ascending=False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2013-01-02  1.0
# 1  foo  train  3  1.0 2013-01-02  1.0
# 2  foo   test  3  1.0 2013-01-02  1.0
# 3  foo  train  3  1.0 2013-01-02  1.0

# %%
df2.sort_values(by="B")
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ## Selection

# %%
df2['A']
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df2[['B', 'A']]
# Out:
#            B    A
# 0 2013-01-02  1.0
# 1 2013-01-02  1.0
# 2 2013-01-02  1.0
# 3 2013-01-02  1.0

# %%
df2[0:3]
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.853757 -0.536522  0.348448  0.259015
# 2013-01-02 -0.245908 -0.194174  0.375606  1.283898
# 2013-01-03 -0.627390  0.278126  0.611421 -0.721866
# 2013-01-04  0.306547 -0.412203 -0.973739  0.130532
# 2013-01-05  0.203389  1.245556  0.254057 -1.223585
# 2013-01-06 -0.195686  0.115979  0.273886 -1.047656

# %% [markdown]
# Access a group of rows and columns by label(s) or a boolean array.
#
# .loc[] is primarily label based, but may also be used with a boolean array.
#
# Allowed inputs are:
#
# A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# A list or array of labels, e.g. ['a', 'b', 'c'].
#
# A slice object with labels, e.g. 'a

# %%
df.loc[dates[0]]
# Out:
# A    0.853757
# B   -0.536522
# C    0.348448
# D    0.259015
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.853757 -0.536522
# 2013-01-02 -0.245908 -0.194174
# 2013-01-03 -0.627390  0.278126
# 2013-01-04  0.306547 -0.412203
# 2013-01-05  0.203389  1.245556
# 2013-01-06 -0.195686  0.115979

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.245908 -0.194174
# 2013-01-03 -0.627390  0.278126
# 2013-01-04  0.306547 -0.412203

# %%
df.loc[dates[0], "A"]
# Out:
# np.float64(0.8537572709077298)

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(0.8537572709077298)

# %%
df.iloc[3]
# Out:
# A    0.306547
# B   -0.412203
# C   -0.973739
# D    0.130532
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.306547 -0.412203
# 2013-01-05  0.203389  1.245556

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.853757 -0.536522  0.348448  0.259015
# 2013-01-02 -0.245908 -0.194174  0.375606  1.283898
# 2013-01-03 -0.627390  0.278126  0.611421 -0.721866
# 2013-01-04  0.306547 -0.412203 -0.973739  0.130532
# 2013-01-05  0.203389  1.245556  0.254057 -1.223585
# 2013-01-06 -0.195686  0.115979  0.273886 -1.047656

# %%
df.iloc[3:,2:]
# Out:
#                    C         D
# 2013-01-04 -0.973739  0.130532
# 2013-01-05  0.254057 -1.223585
# 2013-01-06  0.273886 -1.047656

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.245908  0.375606
# 2013-01-03 -0.627390  0.611421
# 2013-01-05  0.203389  0.254057

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.245908 -0.194174  0.375606  1.283898
# 2013-01-03 -0.627390  0.278126  0.611421 -0.721866

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.536522  0.348448
# 2013-01-02 -0.194174  0.375606
# 2013-01-03  0.278126  0.611421
# 2013-01-04 -0.412203 -0.973739
# 2013-01-05  1.245556  0.254057
# 2013-01-06  0.115979  0.273886

# %%
df.iloc[1,1]
# Out:
# np.float64(-0.19417394793165915)

# %%
df.iat[1,1]
# Out:
# np.float64(-0.19417394793165915)

# %% [markdown]
# ### Boolean Indexing

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.853757 -0.536522  0.348448  0.259015
# 2013-01-04  0.306547 -0.412203 -0.973739  0.130532
# 2013-01-05  0.203389  1.245556  0.254057 -1.223585

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.853757       NaN  0.348448  0.259015
# 2013-01-02       NaN       NaN  0.375606  1.283898
# 2013-01-03       NaN  0.278126  0.611421       NaN
# 2013-01-04  0.306547       NaN       NaN  0.130532
# 2013-01-05  0.203389  1.245556  0.254057       NaN
# 2013-01-06       NaN  0.115979  0.273886       NaN

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.853757 -0.536522  0.348448  0.259015
# 2013-01-02 -0.245908 -0.194174  0.375606  1.283898
# 2013-01-03 -0.627390  0.278126  0.611421 -0.721866
# 2013-01-04  0.306547 -0.412203 -0.973739  0.130532
# 2013-01-05  0.203389  1.245556  0.254057 -1.223585
# 2013-01-06 -0.195686  0.115979  0.273886 -1.047656

# %%
df2=df.copy()
